# %%
# Dùng từ bản gốc
import keras
print(keras.__version__)
# Out:
# 2023-05-09 15:47:48.585954: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 15:47:49.413598: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2.12.0

# %%
from tensorflow import keras
print(keras.__version__)
# Out:
# 2.12.0

# %%
##Note Understand conv2d

# %%
import tensorflow as tf
input_shape = (4,30,30,3)
x = tf.random.normal(input_shape)
y = tf.keras.layers.Conv2D(
 2,3, activation='relu',input_shape=input_shape[1:1]
)(x)
print(y.shape)
# Out:
# 2023-05-09 15:47:52.336340: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:52.409695: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:52.409835: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:52.415159: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:52.415469: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:52.415677: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:53.455995: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:53.456354: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:53.456369: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1722] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-05-09 15:47:53.456423: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:982] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-05-09 15:47:53.456533: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1562 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# 2023-05-09 15:47:56.498210: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# (4, 28, 28, 2)

# %%
#Tao mot CNN vaf View

inputs = keras.layers.Input(shape= [32,32,3],name='smith')

x = keras.layers.Conv2D(filters = 32,kernel_size=3, padding='same', activation='relu')(inputs)
x = keras.layers.Conv2D(filters = 32,kernel_size=3, padding='same', activation='relu')(x)
predictions = keras.layers.MaxPool2D(pool_size=2)(x)

model = keras.Model(inputs = inputs, outputs= predictions)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  smith (InputLayer)          [(None, 32, 32, 3)]       0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 32)        896
#
#  conv2d_4 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
# =================================================================
# Total params: 10,144
# Trainable params: 10,144
# Non-trainable params: 0
# _________________________________________________________________

# %%
predictions.shape
# Out:
# TensorShape([None, 16, 16, 32])

# %%
inputs.shape
# Out:
# TensorShape([None, 32, 32, 3])

# %%
keras.utils.plot_model(model,'model.png',show_shapes=True)
